# %% [markdown]
# ## Модель Transformer-2
# Задание
#
# Взять тот же датасет, который был на вебинаре и предобученную модель для задачи суммаризации
# 1. Проверить насколько хорошо она суммаризирует
# 2.(дополнительно) Сделать генерацию заголовков для статьи (обучить модель для генерации заголовков)

# %%
#установка необходимых библиотек и модулей
# !pip install transformers
# !pip install sentencepiece
# !pip install datasets
# !pip install torchmetrics
# !pip install rouge
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.text import text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.1-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 19.1 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 9.1 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 24.9 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 9.1 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.8.1 pyyaml-6.0 tokenizers-0.12.1 transformers-4.21.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 17.5 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      |████████████████████████████████| 365 kB 32.9 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.12.0)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 73.5 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 58.9 MB/s
# Collecting fsspec[http]>=2021.11.1
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 56.3 MB/s
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.8.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.7.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 58.4 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: urllib3, fsspec, xxhash, responses, multiprocess, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.4.0 fsspec-2022.7.1 multiprocess-0.70.13 responses-0.18.0 urllib3-1.25.11 xxhash-3.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchmetrics
#   Downloading torchmetrics-0.9.3-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 31.5 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (4.1.1)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.12.0+cu113)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.9)
# Installing collected packages: torchmetrics
# Successfully installed torchmetrics-0.9.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from rouge) (1.15.0)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
#загрузка датасета
from datasets import load_dataset
dataset = load_dataset('IlyaGusev/gazeta', revision="v1.0")
# Out:
# Downloading builder script:   0%|          | 0.00/2.98k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/3.87k [00:00<?, ?B/s]
# No config specified, defaulting to: gazeta/default
# Downloading and preparing dataset gazeta/default (download: 545.11 MiB, generated: 542.44 MiB, post-processed: Unknown size, total: 1.06 GiB) to /root/.cache/huggingface/datasets/IlyaGusev___gazeta/default/1.0.0/ef9349c3c0f3112ca4036520d76c4bc1b8a79d30bc29643c6cae5a094d44e457...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/48.6M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/52.1M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/52400 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5770 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/5265 [00:00<?, ? examples/s]
# Dataset gazeta downloaded and prepared to /root/.cache/huggingface/datasets/IlyaGusev___gazeta/default/1.0.0/ef9349c3c0f3112ca4036520d76c4bc1b8a79d30bc29643c6cae5a094d44e457. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#структура датасета
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'summary', 'title', 'date', 'url'],
#         num_rows: 52400
#     })
#     test: Dataset({
#         features: ['text', 'summary', 'title', 'date', 'url'],
#         num_rows: 5770
#     })
#     validation: Dataset({
#         features: ['text', 'summary', 'title', 'date', 'url'],
#         num_rows: 5265
#     })
# })

# %%
#тренировочный датасет
import pandas as pd
df_train = pd.DataFrame(dataset['train'])
df_train.head()
# Out:
#                                                 text  \
# 0  «По итогам 2011 года чистый отток может состав...
# 1  Российское подразделение интернет-корпорации G...
# 2  Басманный районный суд Москвы вечером 6 феврал...
# 3  Как повлияло вступление в ВТО на конкурентносп...
# 4  К третьему сезону «Голос» на Первом канале ста...
#
#                                              summary  \
# 0  В 2011 году из России уйдет $80 млрд, считают ...
# 1  Юлия Соловьева, экс-директор холдинга «Профмед...
# 2  Суд арестовал на два месяца четверых экс-чинов...
# 3  Мнения предпринимателей по поводу вступления в...
# 4  На Первом канале завершился третий сезон шоу «...
#
#                                          title                 date  \
# 0               Прогноз не успевает за оттоком  2011-11-30 18:33:39
# 1                        Google закончил поиск  2013-01-24 18:20:09
# 2  «Фигуранты дела могут давить на свидетелей»  2018-02-06 21:21:14
# 3  «С последних традиционно «отжимают» больше»  2013-06-21 17:43:50
# 4                  Третий «Голос» за Градского  2014-12-27 01:10:01
#
#                                                  url
# 0  https://www.gazeta.ru/financial/2011/11/30/385...
# 1  https://www.gazeta.ru/business/2013/01/24/4939...
# 2  https://www.gazeta.ru/social/2018/02/06/116393...
# 3  https://www.gazeta.ru/business/2013/06/21/5388...
# 4  https://www.gazeta.ru/culture/2014/12/27/a_636...

# %%
#валидационный датасет
df_val = pd.DataFrame(dataset['validation'])
df_val.head()
# Out:
#                                                 text  \
# 0  После громких приобретений Андре Шюррле, Гуса ...
# 1  Американское издание The National Interest оце...
# 2  Министр иностранных дел России Сергей Лавров с...
# 3  Минфин предложил с января 2020 года увеличить ...
# 4  Заявление командующего военно-воздушными силам...
#
#                                              summary  \
# 0  Московский «Спартак» продолжает активную транс...
# 1  Издание The National Interest оценило перспект...
# 2  Глава МИД России Сергей Лавров заявил, что в 2...
# 3  Министерство финансов предлагает вдвое поднять...
# 4  Американские ПВО провалились в Саудовской Арав...
#
#                                                title                 date  \
# 0       Замена Фернандо: кого может купить «Спартак»  2019-08-11 23:14:58
# 1  Шестое поколение: в США оценили российский бом...  2019-08-11 21:16:04
# 2  «Зачем гонять людей?»: США требуют новый рефер...  2019-06-06 09:47:35
# 3  Перейти на отечественное: что будет с зарубежн...  2019-07-24 20:38:15
# 4  «Глупое заявление»: Медведев напомнил о провал...  2019-09-20 21:16:22
#
#                                                  url
# 0  https://www.gazeta.ru/sport/2019/08/11/a_12572...
# 1  https://www.gazeta.ru/army/2019/08/11/12572317...
# 2  https://www.gazeta.ru/politics/2019/06/06_a_12...
# 3  https://www.gazeta.ru/business/2019/07/24/1252...
# 4  https://www.gazeta.ru/army/2019/09/20/12664933...

# %%
#тестовый датасет
df_test = pd.DataFrame(dataset['test'])
df_test.head()
# Out:
#                                                 text  \
# 0  Американское аэрокосмическое агентство NASA ог...
# 1  Около 11 тысяч зрителей увидели все самое лучш...
# 2  7 ноября в Белоруссии прошли выборы членов сов...
# 3  Народная артистка РСФСР Надежда Бабкина в инте...
# 4  Депутат Верховной рады от партии «Слуга народа...
#
#                                              summary  \
# 0  В NASA назвали четыре миссии в дальний космос,...
# 1  25 и 26 февраля в Кремлевском дворце съездов п...
# 2  В Белоруссии в день годовщины Октябрьской рево...
# 3  Народная артистка РСФСР Надежда Бабкина в инте...
# 4  Украина не должна выплачивать пенсии жителям Д...
#
#                                                title                 date  \
# 0           Венера, Ио или Тритон: куда полетит NASA  2020-02-14 16:39:11
# 1                 «Люди в Бурятии очень талантливые»  2020-02-28 10:44:13
# 2        Вспомнить СССР: как Лукашенко провел выборы  2019-11-07 19:55:08
# 3  «Он очень переживал»: Бабкина об отношениях с ...  2020-03-01 16:50:06
# 4  «Поддерживают Россию»: почему Киев не платит п...  2020-02-06 12:41:24
#
#                                                  url
# 0  https://www.gazeta.ru/science/2020/02/14_a_129...
# 1  https://www.gazeta.ru/social/2020/02/28/129806...
# 2  https://www.gazeta.ru/politics/2019/11/07_a_12...
# 3  https://www.gazeta.ru/culture/2020/03/01/a_129...
# 4  https://www.gazeta.ru/business/2020/02/06/1294...

# %% [markdown]
# Предобученная модель summarization IlyaGusev/rut5_base_sum_gazeta

# %%
#загрузка и инициализация модели
from transformers import AutoTokenizer, T5ForConditionalGeneration

model_name = "IlyaGusev/rut5_base_sum_gazeta"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

#пример работы модели
article_text = df_test['text'][1]

input_ids = tokenizer(
    [article_text],
    max_length=600,
    add_special_tokens=True,
    padding="max_length",
    truncation=True,
    return_tensors="pt"
)["input_ids"]

output_ids = model.generate(
    input_ids=input_ids,
    no_repeat_ngram_size=4
)[0]

summary = tokenizer.decode(output_ids, skip_special_tokens=True)
print(summary)
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/279 [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/808k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.25M [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/766 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/932M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1207: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 200 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# В Кремле прошло праздничное шоу «Танцуют все!» на телеканале «Россия». Зрителям рассказали, что в Бурятии сохранилась и развивается культура десятков национальностей, включая русских, бурятов, староверов и эвенков.

# %%
#функция подсчета метрик
from nltk.translate.bleu_score import corpus_bleu
from rouge import Rouge

def calc_scores(references, predictions, metric="all"):
    print("Count:", len(predictions))
    print("Ref:", references[-1])
    print("Hyp:", predictions[-1])

    if metric in ("bleu", "all"):
        print("BLEU: ", corpus_bleu([[r] for r in references], predictions))
    if metric in ("rouge", "all"):
        rouge = Rouge()
        scores = rouge.get_scores(predictions, references, avg=True)
        print("ROUGE: ", scores)

# %%
#подсчет метрик на примере предсказания модели
import nltk
nltk.download('punkt')
from nltk import sent_tokenize
target = sent_tokenize(df_test['summary'][1])
preds = sent_tokenize(summary)
calc_scores(target, preds)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Count: 2
# Ref: Бурятия - центр российского буддизма и один из немногих регионов страны, где новый год встречают официально дважды.
# Hyp: Зрителям рассказали, что в Бурятии сохранилась и развивается культура десятков национальностей, включая русских, бурятов, староверов и эвенков.
# BLEU:  0.19334823151545613
# ROUGE:  {'rouge-1': {'r': 0.029411764705882353, 'p': 0.03125, 'f': 0.030303027805326194}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.029411764705882353, 'p': 0.03125, 'f': 0.030303027805326194}}

# %% [markdown]
# Обучение модели

# %%
#добавляем токены начала и конца предложения
df_train['title_clean'] = df_train['title'].apply(lambda v: 'BOS ' + v + ' EOS')
df_test['title_clean'] = df_test['title'].apply(lambda v: 'BOS ' + v + ' EOS')

# %%
df_test['title_clean']
# Out:
# 0        BOS Венера, Ио или Тритон: куда полетит NASA EOS
# 1              BOS «Люди в Бурятии очень талантливые» EOS
# 2       BOS Вспомнить СССР: как Лукашенко провел выбор...
# 3       BOS «Он очень переживал»: Бабкина об отношения...
# 4       BOS «Поддерживают Россию»: почему Киев не плат...
#                               ...
# 5765    BOS Новая «Игра престолов»? Netflix показал тр...
# 5766    BOS «Это было ужасно»: Джоли эвакуировали со с...
# 5767    BOS «Это камни»: ученого затравили за змей на ...
# 5768    BOS «До 200 тысяч зараженных»: как распростран...
# 5769    BOS С российским реактором: Китай создаст атом...
# Name: title_clean, Length: 5770, dtype: object

# %%
#уменьшаем объем датасетов
MAX_TRAIN_SAMPLE = 1000
MAX_TEST_SAMPLE = 200

df_train = df_train[:MAX_TRAIN_SAMPLE]
df_test = df_test[:MAX_TEST_SAMPLE]

# %%
max_len_text = 700
max_len_sum = 50

# %%
tok_text = Tokenizer()
#создаем словарь индексов на основе частоты слов в df_train['text'] (чем меньше число, тем чаще встречается слово)
tok_text.fit_on_texts(df_train['text'])
#преобразуем каждый text из df_train['text'] в последовательность целых чисел  в соответсвии со словарем
x_train_tok = tok_text.texts_to_sequences(df_train['text'])
x_test_tok = tok_text.texts_to_sequences(df_test['text'])

# %%
text_vocab_size=len(tok_text.word_index)+1
#приводим последовательности целых чисел к одной длине:
#к каждому элементу из x_train_tok добавляем (отнимаем) до max_len_text (от max_len_text) нулями сзади
padded_x_train = pad_sequences(x_train_tok, maxlen=max_len_text, padding='post', truncating='post')
padded_x_test = pad_sequences(x_test_tok, maxlen=max_len_text, padding='post', truncating='post')

# %%
padded_x_train.shape
# Out:
# (1000, 700)

# %%
tok_sum = Tokenizer()
#создаем словарь индексов на основе частоты слов в df_train['title_clean']
tok_sum.fit_on_texts(df_train['title_clean'])
#преобразуем каждый text из df_train['title_clean'] в последовательность целых чисел  в соответсвии со словарем
x_train_sum = tok_sum.texts_to_sequences(df_train['title_clean'])
x_test_sum = tok_sum.texts_to_sequences(df_test['title_clean'])

# %%
sum_vocab_size=len(tok_sum.word_index)+1
#приводим последовательности целых чисел к одной длине:
#к каждому элементу из x_train_tok добавляем (отнимаем) до max_len_sum (от max_len_sum) нулями сзади
padded_x_train_sum = pad_sequences(x_train_sum, maxlen=max_len_sum, padding='post', truncating='post')
padded_x_test_sum = pad_sequences(x_test_sum, maxlen=max_len_sum, padding='post', truncating='post')

# %%
padded_x_train_sum.shape
# Out:
# (1000, 50)

# %%
#словарь индекс: токен для tok_text
reverse_text_index=tok_text.index_word
#словарь индекс: токен для tok_sum
reverse_sum_index=tok_sum.index_word
#словарь токен: индекс для tok_sum
sum_wordindex=tok_sum.word_index

# %%
from tensorflow.keras.layers import GRU, AdditiveAttention

# %%
BUFFER_SIZE = len(padded_x_train)
BATCH_SIZE = 32
steps_per_epoch = len(padded_x_train)//BATCH_SIZE

#каждую пару (padded_x_train, padded_x_train_sum) преобразуем в тензор
dataset = tf.data.Dataset.from_tensor_slices((padded_x_train, padded_x_train_sum)).shuffle(BUFFER_SIZE)
#объединяем последоваетльные элементы в батчи, неполный батч удаляем
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
for element in dataset:
  print(element)
  break
# Out:
# (<tf.Tensor: shape=(32, 700), dtype=int32, numpy=
# array([[   59,   942,   224, ...,     0,     0,     0],
#        [    1,   556,     8, ...,  4285,  2526,  6254],
#        [  105,    57,  2057, ...,     0,     0,     0],
#        ...,
#        [ 2739,  5285, 38354, ...,   718,     2,   918],
#        [  170,  3584,  3945, ...,   392,  3829,     9],
#        [ 2064, 88152,  1826, ..., 17100,  5186,     2]], dtype=int32)>, <tf.Tensor: shape=(32, 50), dtype=int32, numpy=
# array([[   1, 1046, 1047, ...,    0,    0,    0],
#        [   1, 2928, 2929, ...,    0,    0,    0],
#        [   1, 1192, 1193, ...,    0,    0,    0],
#        ...,
#        [   1, 2535,    6, ...,    0,    0,    0],
#        [   1,   10, 3329, ...,    0,    0,    0],
#        [   1, 3373,    4, ...,    0,    0,    0]], dtype=int32)>)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([32, 700]), TensorShape([32, 50]))

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru1 = tf.keras.layers.GRU(self.enc_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.gru2 = tf.keras.layers.GRU(self.enc_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')

    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru1(x, initial_state = hidden)
        output, state = self.gru2(output, initial_state = state)
        return output, state

    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))
    
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc = tf.keras.layers.Dense(vocab_size)

        # used for attention
        self.attention = tf.keras.layers.AdditiveAttention()

    def call(self, x, query, value):
        # enc_output shape == (batch_size, max_length, hidden_size)
        #attention_weights = self.attention([ tf.expand_dims(query, 1), value,])
        context_vector = self.attention([tf.expand_dims(query, 1), value,])
        #context_vector = tf.squeeze(context_vector)


        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)
        # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        x = tf.concat([context_vector, x], axis=-1)

        # passing the concatenated vector to the GRU
        output, state = self.gru(x)

        # output shape == (batch_size * 1, hidden_size)
        output = tf.reshape(output, (-1, output.shape[2]))

        # output shape == (batch_size, vocab)
        x = self.fc(output)

        return x, state

# %%
latent_dim = 300
embedding_dim=200

#создаем экземпляры encoder и decoder
encoder = Encoder(text_vocab_size, embedding_dim, latent_dim, BATCH_SIZE)
decoder = Decoder(sum_vocab_size, embedding_dim, latent_dim, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)

# %%
sample_output
# Out:
# <tf.Tensor: shape=(32, 700, 300), dtype=float32, numpy=
# array([[[ 2.5179940e-03,  3.5979103e-03, -2.8618123e-02, ...,
#           1.5579304e-02,  4.9766186e-03, -1.2617163e-02],
#         [-4.2747706e-03,  2.2504989e-03, -1.7214295e-02, ...,
#           8.5284403e-03,  1.0011270e-02, -1.3205533e-02],
#         [-3.4195813e-03, -1.7985738e-03, -8.7113930e-03, ...,
#           1.8043926e-03,  1.7636014e-02, -4.2049726e-03],
#         ...,
#         [-1.1704090e-02, -2.6550369e-02, -2.3126155e-03, ...,
#           1.4269983e-03, -7.6779798e-03,  1.7334690e-02],
#         [-1.1704090e-02, -2.6550369e-02, -2.3126155e-03, ...,
#           1.4269983e-03, -7.6779802e-03,  1.7334690e-02],
#         [-1.1704090e-02, -2.6550369e-02, -2.3126155e-03, ...,
#           1.4269988e-03, -7.6779802e-03,  1.7334690e-02]],
#
#        [[ 5.8339597e-03,  3.9438666e-03, -3.4050401e-02, ...,
#           1.2703922e-02,  3.0688825e-03, -7.1917349e-03],
#         [ 6.1673336e-03, -1.5698432e-03, -2.2944508e-02, ...,
#           6.7749433e-03,  4.8674736e-03, -6.4385398e-03],
#         [ 1.1360173e-03, -2.9155982e-03, -1.7416911e-02, ...,
#           1.5813288e-03,  6.4286757e-03, -3.6400023e-03],
#         ...,
#         [-1.1704091e-02, -2.6550369e-02, -2.3126130e-03, ...,
#           1.4270007e-03, -7.6779770e-03,  1.7334692e-02],
#         [-1.1704092e-02, -2.6550369e-02, -2.3126132e-03, ...,
#           1.4270000e-03, -7.6779765e-03,  1.7334692e-02],
#         [-1.1704092e-02, -2.6550369e-02, -2.3126134e-03, ...,
#           1.4269997e-03, -7.6779765e-03,  1.7334692e-02]],
#
#        [[-5.7064011e-03,  5.8443206e-03,  6.0085324e-03, ...,
#           3.4324208e-04, -1.2948900e-03,  8.6880969e-03],
#         [-5.0331280e-03,  7.0498092e-03, -5.9604703e-04, ...,
#           1.6078135e-05, -9.6156570e-04,  4.8527298e-03],
#         [-6.6766734e-03,  8.9860614e-03,  5.5741885e-04, ...,
#          -2.1955855e-03, -7.8684418e-04,  2.6324802e-04],
#         ...,
#         [ 7.7993292e-03,  3.5248145e-03,  4.1321866e-04, ...,
#           5.2817860e-03, -7.7443421e-03,  2.5407763e-03],
#         [ 6.9376370e-03,  3.4432833e-03, -1.3823757e-03, ...,
#           7.5845481e-03, -1.1445366e-02,  6.2588654e-03],
#         [ 1.0580588e-02,  5.2818074e-04,  9.0393884e-04, ...,
#           6.4384136e-03, -5.8356109e-03,  1.2413608e-02]],
#
#        ...,
#
#        [[-1.4636874e-03,  1.0640706e-02, -2.7651723e-02, ...,
#           1.9749120e-02,  1.7724758e-03, -1.3752922e-02],
#         [ 3.2302467e-04,  9.1046300e-03, -1.4022558e-02, ...,
#           1.6602051e-02,  4.8302971e-03, -3.6225824e-03],
#         [ 1.4976744e-03,  3.2154049e-03, -2.1284111e-04, ...,
#           1.3096687e-02,  1.2587683e-03,  2.9260283e-03],
#         ...,
#         [-1.1148232e-02, -2.5453117e-02, -1.5311379e-03, ...,
#           1.6582302e-03, -7.8634331e-03,  1.6222714e-02],
#         [-1.1309727e-02, -2.5854146e-02, -1.7351578e-03, ...,
#           1.5625330e-03, -7.8360271e-03,  1.6626742e-02],
#         [-1.1418594e-02, -2.6106149e-02, -1.8990280e-03, ...,
#           1.5081577e-03, -7.7997562e-03,  1.6889634e-02]],
#
#        [[ 2.8789204e-03,  4.5077731e-03, -3.1030279e-02, ...,
#           1.5720407e-02,  2.9458716e-03, -7.3491982e-03],
#         [ 2.1045066e-03, -1.2885912e-03, -1.4285923e-02, ...,
#           1.0022498e-02,  4.8443396e-03,  1.7685684e-03],
#         [ 1.0181469e-03, -8.3337014e-04, -5.2948343e-03, ...,
#           6.4098318e-03,  9.4289030e-04,  6.9922525e-03],
#         ...,
#         [-1.1704089e-02, -2.6550367e-02, -2.3126132e-03, ...,
#           1.4269998e-03, -7.6779798e-03,  1.7334696e-02],
#         [-1.1704089e-02, -2.6550367e-02, -2.3126132e-03, ...,
#           1.4269998e-03, -7.6779798e-03,  1.7334696e-02],
#         [-1.1704089e-02, -2.6550367e-02, -2.3126132e-03, ...,
#           1.4269998e-03, -7.6779798e-03,  1.7334696e-02]],
#
#        [[ 2.2414348e-03,  4.0424783e-03, -2.7433999e-02, ...,
#           2.0069726e-02, -1.6036039e-03, -6.7858887e-03],
#         [ 4.2829500e-03, -1.1916480e-03, -2.0504318e-02, ...,
#           2.0271853e-02,  3.4786169e-03, -1.0051749e-03],
#         [ 7.7348468e-03, -3.8517648e-03, -1.3925073e-02, ...,
#           2.4434352e-02,  9.1771297e-03,  2.3352043e-03],
#         ...,
#         [-1.1704088e-02, -2.6550369e-02, -2.3126157e-03, ...,
#           1.4269995e-03, -7.6779774e-03,  1.7334692e-02],
#         [-1.1704088e-02, -2.6550369e-02, -2.3126150e-03, ...,
#           1.4269991e-03, -7.6779779e-03,  1.7334692e-02],
#         [-1.1704088e-02, -2.6550369e-02, -2.3126148e-03, ...,
#           1.4269990e-03, -7.6779779e-03,  1.7334692e-02]]], dtype=float32)>

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    # определяем ненулевые элементы
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)
    #переводим mask к типу loss_
    mask = tf.cast(mask, dtype=loss_.dtype)
    #умножаем loss на маску
    loss_ *= mask

    return tf.reduce_mean(loss_) #возвращаем среднее значение элементов тензора

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0

    with tf.GradientTape() as tape:
        enc_output, enc_hidden = encoder(inp, enc_hidden)

        dec_hidden = enc_hidden

        dec_input = tf.expand_dims([sum_wordindex['bos']] * BATCH_SIZE, 1)

        # Teacher forcing - feeding the target as the next input
        for t in range(1, targ.shape[1]):
            # passing enc_output to the decoder
            predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_output)

            loss += loss_function(targ[:, t], predictions)

            # using teacher forcing
            dec_input = tf.expand_dims(targ[:, t], 1)

    batch_loss = (loss / int(targ.shape[1]))

    variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, variables)

    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %%
import unicodedata
import re
import numpy as np
import os
import io
import time

checkpoint_dir = './training_summ_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
EPOCHS = 200

for epoch in range(EPOCHS):
    start = time.time()

    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0

    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
        batch_loss = train_step(inp, targ, enc_hidden)
        total_loss += batch_loss

        if batch % 10 == 0:
            print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                     batch,
                                                     batch_loss.numpy()))
    # saving (checkpoint) the model every 2 epochs
    if (epoch + 1) % 2 == 0:
        checkpoint.save(file_prefix = checkpoint_prefix)

    print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 0.9702
# Epoch 1 Batch 10 Loss 0.7338
# Epoch 1 Batch 20 Loss 0.9398
# Epoch 1 Batch 30 Loss 0.8081
# Epoch 1 Loss 0.8992
# Time taken for 1 epoch 69.36727547645569 sec
#
# Epoch 2 Batch 0 Loss 0.8316
# Epoch 2 Batch 10 Loss 0.8717
# Epoch 2 Batch 20 Loss 0.7910
# Epoch 2 Batch 30 Loss 0.8135
# Epoch 2 Loss 0.8272
# Time taken for 1 epoch 9.736235857009888 sec
#
# Epoch 3 Batch 0 Loss 0.7538
# Epoch 3 Batch 10 Loss 0.8101
# Epoch 3 Batch 20 Loss 0.7928
# Epoch 3 Batch 30 Loss 0.7540
# Epoch 3 Loss 0.7972
# Time taken for 1 epoch 9.085978746414185 sec
#
# Epoch 4 Batch 0 Loss 0.7504
# Epoch 4 Batch 10 Loss 0.7830
# Epoch 4 Batch 20 Loss 0.7955
# Epoch 4 Batch 30 Loss 0.7691
# Epoch 4 Loss 0.7733
# Time taken for 1 epoch 9.668677806854248 sec
#
# Epoch 5 Batch 0 Loss 0.8603
# Epoch 5 Batch 10 Loss 0.8266
# Epoch 5 Batch 20 Loss 0.7443
# Epoch 5 Batch 30 Loss 0.7134
# Epoch 5 Loss 0.7564
# Time taken for 1 epoch 9.287279605865479 sec
#
# Epoch 6 Batch 0 Loss 0.7111
# Epoch 6 Batch 10 Loss 0.7326
# Epoch 6 Batch 20 Loss 0.7599
# Epoch 6 Batch 30 Loss 0.6892
# Epoch 6 Loss 0.7389
# Time taken for 1 epoch 10.7773597240448 sec
#
# Epoch 7 Batch 0 Loss 0.7544
# Epoch 7 Batch 10 Loss 0.6915
# Epoch 7 Batch 20 Loss 0.6277
# Epoch 7 Batch 30 Loss 0.7132
# Epoch 7 Loss 0.7227
# Time taken for 1 epoch 9.231182098388672 sec
#
# Epoch 8 Batch 0 Loss 0.7531
# Epoch 8 Batch 10 Loss 0.7869
# Epoch 8 Batch 20 Loss 0.7499
# Epoch 8 Batch 30 Loss 0.6868
# Epoch 8 Loss 0.7044
# Time taken for 1 epoch 9.872700214385986 sec
#
# Epoch 9 Batch 0 Loss 0.6708
# Epoch 9 Batch 10 Loss 0.7475
# Epoch 9 Batch 20 Loss 0.6848
# Epoch 9 Batch 30 Loss 0.6758
# Epoch 9 Loss 0.6861
# Time taken for 1 epoch 9.321463584899902 sec
#
# Epoch 10 Batch 0 Loss 0.6996
# Epoch 10 Batch 10 Loss 0.5586
# Epoch 10 Batch 20 Loss 0.7806
# Epoch 10 Batch 30 Loss 0.7027
# Epoch 10 Loss 0.6652
# Time taken for 1 epoch 9.95733904838562 sec
#
# Epoch 11 Batch 0 Loss 0.6332
# Epoch 11 Batch 10 Loss 0.6076
# Epoch 11 Batch 20 Loss 0.5824
# Epoch 11 Batch 30 Loss 0.6176
# Epoch 11 Loss 0.6454
# Time taken for 1 epoch 9.313270330429077 sec
#
# Epoch 12 Batch 0 Loss 0.5952
# Epoch 12 Batch 10 Loss 0.6158
# Epoch 12 Batch 20 Loss 0.5216
# Epoch 12 Batch 30 Loss 0.5966
# Epoch 12 Loss 0.6303
# Time taken for 1 epoch 9.868520975112915 sec
#
# Epoch 13 Batch 0 Loss 0.5709
# Epoch 13 Batch 10 Loss 0.5915
# Epoch 13 Batch 20 Loss 0.7224
# Epoch 13 Batch 30 Loss 0.6491
# Epoch 13 Loss 0.6113
# Time taken for 1 epoch 9.280561447143555 sec
#
# Epoch 14 Batch 0 Loss 0.5844
# Epoch 14 Batch 10 Loss 0.5355
# Epoch 14 Batch 20 Loss 0.5519
# Epoch 14 Batch 30 Loss 0.6246
# Epoch 14 Loss 0.5958
# Time taken for 1 epoch 9.855709314346313 sec
#
# Epoch 15 Batch 0 Loss 0.5795
# Epoch 15 Batch 10 Loss 0.5197
# Epoch 15 Batch 20 Loss 0.5541
# Epoch 15 Batch 30 Loss 0.5902
# Epoch 15 Loss 0.5827
# Time taken for 1 epoch 9.26187252998352 sec
#
# Epoch 16 Batch 0 Loss 0.5518
# Epoch 16 Batch 10 Loss 0.5231
# Epoch 16 Batch 20 Loss 0.5787
# Epoch 16 Batch 30 Loss 0.5838
# Epoch 16 Loss 0.5656
# Time taken for 1 epoch 9.875533103942871 sec
#
# Epoch 17 Batch 0 Loss 0.5388
# Epoch 17 Batch 10 Loss 0.5149
# Epoch 17 Batch 20 Loss 0.4853
# Epoch 17 Batch 30 Loss 0.5440
# Epoch 17 Loss 0.5493
# Time taken for 1 epoch 9.263832092285156 sec
#
# Epoch 18 Batch 0 Loss 0.5394
# Epoch 18 Batch 10 Loss 0.5570
# Epoch 18 Batch 20 Loss 0.4949
# Epoch 18 Batch 30 Loss 0.4982
# Epoch 18 Loss 0.5322
# Time taken for 1 epoch 9.961507797241211 sec
#
# Epoch 19 Batch 0 Loss 0.5495
# Epoch 19 Batch 10 Loss 0.4749
# Epoch 19 Batch 20 Loss 0.5560
# Epoch 19 Batch 30 Loss 0.5125
# Epoch 19 Loss 0.5164
# Time taken for 1 epoch 9.294772148132324 sec
#
# Epoch 20 Batch 0 Loss 0.4883
# Epoch 20 Batch 10 Loss 0.5079
# Epoch 20 Batch 20 Loss 0.5334
# Epoch 20 Batch 30 Loss 0.5288
# Epoch 20 Loss 0.5007
# Time taken for 1 epoch 9.9013512134552 sec
#
# Epoch 21 Batch 0 Loss 0.3911
# Epoch 21 Batch 10 Loss 0.4585
# Epoch 21 Batch 20 Loss 0.5188
# Epoch 21 Batch 30 Loss 0.5087
# Epoch 21 Loss 0.4881
# Time taken for 1 epoch 9.272422552108765 sec
#
# Epoch 22 Batch 0 Loss 0.4840
# Epoch 22 Batch 10 Loss 0.4420
# Epoch 22 Batch 20 Loss 0.5255
# Epoch 22 Batch 30 Loss 0.4547
# Epoch 22 Loss 0.4737
# Time taken for 1 epoch 9.859384775161743 sec
#
# Epoch 23 Batch 0 Loss 0.4572
# Epoch 23 Batch 10 Loss 0.4455
# Epoch 23 Batch 20 Loss 0.5060
# Epoch 23 Batch 30 Loss 0.5173
# Epoch 23 Loss 0.4602
# Time taken for 1 epoch 9.2984619140625 sec
#
# Epoch 24 Batch 0 Loss 0.4537
# Epoch 24 Batch 10 Loss 0.3634
# Epoch 24 Batch 20 Loss 0.5280
# Epoch 24 Batch 30 Loss 0.4369
# Epoch 24 Loss 0.4453
# Time taken for 1 epoch 9.896766901016235 sec
#
# Epoch 25 Batch 0 Loss 0.4011
# Epoch 25 Batch 10 Loss 0.4276
# Epoch 25 Batch 20 Loss 0.4592
# Epoch 25 Batch 30 Loss 0.4566
# Epoch 25 Loss 0.4293
# Time taken for 1 epoch 9.290312051773071 sec
#
# Epoch 26 Batch 0 Loss 0.3405
# Epoch 26 Batch 10 Loss 0.3441
# Epoch 26 Batch 20 Loss 0.3842
# Epoch 26 Batch 30 Loss 0.4080
# Epoch 26 Loss 0.4106
# Time taken for 1 epoch 9.90950059890747 sec
#
# Epoch 27 Batch 0 Loss 0.3921
# Epoch 27 Batch 10 Loss 0.3735
# Epoch 27 Batch 20 Loss 0.4369
# Epoch 27 Batch 30 Loss 0.4341
# Epoch 27 Loss 0.3981
# Time taken for 1 epoch 9.281652212142944 sec
#
# Epoch 28 Batch 0 Loss 0.3777
# Epoch 28 Batch 10 Loss 0.3368
# Epoch 28 Batch 20 Loss 0.3550
# Epoch 28 Batch 30 Loss 0.4094
# Epoch 28 Loss 0.3825
# Time taken for 1 epoch 9.894490480422974 sec
#
# Epoch 29 Batch 0 Loss 0.3710
# Epoch 29 Batch 10 Loss 0.3616
# Epoch 29 Batch 20 Loss 0.3423
# Epoch 29 Batch 30 Loss 0.3500
# Epoch 29 Loss 0.3620
# Time taken for 1 epoch 9.283680438995361 sec
#
# Epoch 30 Batch 0 Loss 0.3161
# Epoch 30 Batch 10 Loss 0.3554
# Epoch 30 Batch 20 Loss 0.3521
# Epoch 30 Batch 30 Loss 0.3565
# Epoch 30 Loss 0.3440
# Time taken for 1 epoch 9.890809535980225 sec
#
# Epoch 31 Batch 0 Loss 0.2831
# Epoch 31 Batch 10 Loss 0.3430
# Epoch 31 Batch 20 Loss 0.3413
# Epoch 31 Batch 30 Loss 0.3683
# Epoch 31 Loss 0.3251
# Time taken for 1 epoch 9.279444932937622 sec
#
# Epoch 32 Batch 0 Loss 0.3006
# Epoch 32 Batch 10 Loss 0.3230
# Epoch 32 Batch 20 Loss 0.3069
# Epoch 32 Batch 30 Loss 0.3218
# Epoch 32 Loss 0.3085
# Time taken for 1 epoch 9.816059589385986 sec
#
# Epoch 33 Batch 0 Loss 0.3031
# Epoch 33 Batch 10 Loss 0.2797
# Epoch 33 Batch 20 Loss 0.2926
# Epoch 33 Batch 30 Loss 0.2999
# Epoch 33 Loss 0.2903
# Time taken for 1 epoch 9.2779061794281 sec
#
# Epoch 34 Batch 0 Loss 0.2704
# Epoch 34 Batch 10 Loss 0.2660
# Epoch 34 Batch 20 Loss 0.2855
# Epoch 34 Batch 30 Loss 0.2888
# Epoch 34 Loss 0.2750
# Time taken for 1 epoch 10.012877464294434 sec
#
# Epoch 35 Batch 0 Loss 0.2274
# Epoch 35 Batch 10 Loss 0.2537
# Epoch 35 Batch 20 Loss 0.2327
# Epoch 35 Batch 30 Loss 0.2883
# Epoch 35 Loss 0.2621
# Time taken for 1 epoch 9.280888319015503 sec
#
# Epoch 36 Batch 0 Loss 0.1990
# Epoch 36 Batch 10 Loss 0.2274
# Epoch 36 Batch 20 Loss 0.2485
# Epoch 36 Batch 30 Loss 0.2473
# Epoch 36 Loss 0.2469
# Time taken for 1 epoch 9.883934259414673 sec
#
# Epoch 37 Batch 0 Loss 0.2112
# Epoch 37 Batch 10 Loss 0.2302
# Epoch 37 Batch 20 Loss 0.2260
# Epoch 37 Batch 30 Loss 0.2266
# Epoch 37 Loss 0.2301
# Time taken for 1 epoch 9.292168140411377 sec
#
# Epoch 38 Batch 0 Loss 0.1887
# Epoch 38 Batch 10 Loss 0.2172
# Epoch 38 Batch 20 Loss 0.2367
# Epoch 38 Batch 30 Loss 0.2505
# Epoch 38 Loss 0.2162
# Time taken for 1 epoch 9.936501741409302 sec
#
# Epoch 39 Batch 0 Loss 0.1919
# Epoch 39 Batch 10 Loss 0.2056
# Epoch 39 Batch 20 Loss 0.2301
# Epoch 39 Batch 30 Loss 0.2195
# Epoch 39 Loss 0.2027
# Time taken for 1 epoch 9.269727230072021 sec
#
# Epoch 40 Batch 0 Loss 0.1789
# Epoch 40 Batch 10 Loss 0.1879
# Epoch 40 Batch 20 Loss 0.2206
# Epoch 40 Batch 30 Loss 0.1909
# Epoch 40 Loss 0.1908
# Time taken for 1 epoch 10.156718254089355 sec
#
# Epoch 41 Batch 0 Loss 0.1587
# Epoch 41 Batch 10 Loss 0.1648
# Epoch 41 Batch 20 Loss 0.1895
# Epoch 41 Batch 30 Loss 0.1864
# Epoch 41 Loss 0.1787
# Time taken for 1 epoch 9.289018869400024 sec
#
# Epoch 42 Batch 0 Loss 0.1504
# Epoch 42 Batch 10 Loss 0.1596
# Epoch 42 Batch 20 Loss 0.1851
# Epoch 42 Batch 30 Loss 0.1859
# Epoch 42 Loss 0.1679
# Time taken for 1 epoch 9.864580869674683 sec
#
# Epoch 43 Batch 0 Loss 0.1552
# Epoch 43 Batch 10 Loss 0.1478
# Epoch 43 Batch 20 Loss 0.1628
# Epoch 43 Batch 30 Loss 0.2108
# Epoch 43 Loss 0.1581
# Time taken for 1 epoch 9.274434089660645 sec
#
# Epoch 44 Batch 0 Loss 0.1273
# Epoch 44 Batch 10 Loss 0.1361
# Epoch 44 Batch 20 Loss 0.1443
# Epoch 44 Batch 30 Loss 0.1602
# Epoch 44 Loss 0.1483
# Time taken for 1 epoch 9.914560556411743 sec
#
# Epoch 45 Batch 0 Loss 0.1288
# Epoch 45 Batch 10 Loss 0.1422
# Epoch 45 Batch 20 Loss 0.1354
# Epoch 45 Batch 30 Loss 0.1447
# Epoch 45 Loss 0.1405
# Time taken for 1 epoch 9.28867506980896 sec
#
# Epoch 46 Batch 0 Loss 0.1184
# Epoch 46 Batch 10 Loss 0.1472
# Epoch 46 Batch 20 Loss 0.1317
# Epoch 46 Batch 30 Loss 0.1512
# Epoch 46 Loss 0.1338
# Time taken for 1 epoch 10.010462760925293 sec
#
# Epoch 47 Batch 0 Loss 0.1230
# Epoch 47 Batch 10 Loss 0.1206
# Epoch 47 Batch 20 Loss 0.1318
# Epoch 47 Batch 30 Loss 0.1431
# Epoch 47 Loss 0.1273
# Time taken for 1 epoch 9.31744122505188 sec
#
# Epoch 48 Batch 0 Loss 0.1046
# Epoch 48 Batch 10 Loss 0.1115
# Epoch 48 Batch 20 Loss 0.1248
# Epoch 48 Batch 30 Loss 0.1249
# Epoch 48 Loss 0.1205
# Time taken for 1 epoch 9.902779579162598 sec
#
# Epoch 49 Batch 0 Loss 0.1016
# Epoch 49 Batch 10 Loss 0.1052
# Epoch 49 Batch 20 Loss 0.1132
# Epoch 49 Batch 30 Loss 0.1218
# Epoch 49 Loss 0.1138
# Time taken for 1 epoch 9.311053037643433 sec
#
# Epoch 50 Batch 0 Loss 0.0995
# Epoch 50 Batch 10 Loss 0.1055
# Epoch 50 Batch 20 Loss 0.1130
# Epoch 50 Batch 30 Loss 0.1039
# Epoch 50 Loss 0.1078
# Time taken for 1 epoch 9.99267292022705 sec
#
# Epoch 51 Batch 0 Loss 0.0991
# Epoch 51 Batch 10 Loss 0.1027
# Epoch 51 Batch 20 Loss 0.1075
# Epoch 51 Batch 30 Loss 0.1157
# Epoch 51 Loss 0.1019
# Time taken for 1 epoch 9.298067092895508 sec
#
# Epoch 52 Batch 0 Loss 0.0844
# Epoch 52 Batch 10 Loss 0.0963
# Epoch 52 Batch 20 Loss 0.1075
# Epoch 52 Batch 30 Loss 0.0980
# Epoch 52 Loss 0.0962
# Time taken for 1 epoch 9.89079761505127 sec
#
# Epoch 53 Batch 0 Loss 0.0759
# Epoch 53 Batch 10 Loss 0.0797
# Epoch 53 Batch 20 Loss 0.0935
# Epoch 53 Batch 30 Loss 0.1018
# Epoch 53 Loss 0.0912
# Time taken for 1 epoch 10.235692262649536 sec
#
# Epoch 54 Batch 0 Loss 0.0835
# Epoch 54 Batch 10 Loss 0.0766
# Epoch 54 Batch 20 Loss 0.0897
# Epoch 54 Batch 30 Loss 0.0886
# Epoch 54 Loss 0.0866
# Time taken for 1 epoch 9.878846406936646 sec
#
# Epoch 55 Batch 0 Loss 0.0789
# Epoch 55 Batch 10 Loss 0.0887
# Epoch 55 Batch 20 Loss 0.0767
# Epoch 55 Batch 30 Loss 0.0885
# Epoch 55 Loss 0.0829
# Time taken for 1 epoch 10.233057737350464 sec
#
# Epoch 56 Batch 0 Loss 0.0748
# Epoch 56 Batch 10 Loss 0.0753
# Epoch 56 Batch 20 Loss 0.0724
# Epoch 56 Batch 30 Loss 0.0878
# Epoch 56 Loss 0.0793
# Time taken for 1 epoch 9.909302473068237 sec
#
# Epoch 57 Batch 0 Loss 0.0744
# Epoch 57 Batch 10 Loss 0.0764
# Epoch 57 Batch 20 Loss 0.0743
# Epoch 57 Batch 30 Loss 0.0870
# Epoch 57 Loss 0.0759
# Time taken for 1 epoch 9.29690170288086 sec
#
# Epoch 58 Batch 0 Loss 0.0640
# Epoch 58 Batch 10 Loss 0.0694
# Epoch 58 Batch 20 Loss 0.0784
# Epoch 58 Batch 30 Loss 0.0761
# Epoch 58 Loss 0.0726
# Time taken for 1 epoch 10.040747880935669 sec
#
# Epoch 59 Batch 0 Loss 0.0659
# Epoch 59 Batch 10 Loss 0.0773
# Epoch 59 Batch 20 Loss 0.0785
# Epoch 59 Batch 30 Loss 0.0844
# Epoch 59 Loss 0.0704
# Time taken for 1 epoch 9.303783655166626 sec
#
# Epoch 60 Batch 0 Loss 0.0640
# Epoch 60 Batch 10 Loss 0.0609
# Epoch 60 Batch 20 Loss 0.0777
# Epoch 60 Batch 30 Loss 0.0765
# Epoch 60 Loss 0.0682
# Time taken for 1 epoch 9.87881588935852 sec
#
# Epoch 61 Batch 0 Loss 0.0524
# Epoch 61 Batch 10 Loss 0.0681
# Epoch 61 Batch 20 Loss 0.0612
# Epoch 61 Batch 30 Loss 0.0726
# Epoch 61 Loss 0.0659
# Time taken for 1 epoch 9.280500411987305 sec
#
# Epoch 62 Batch 0 Loss 0.0548
# Epoch 62 Batch 10 Loss 0.0549
# Epoch 62 Batch 20 Loss 0.0678
# Epoch 62 Batch 30 Loss 0.0710
# Epoch 62 Loss 0.0633
# Time taken for 1 epoch 9.910888671875 sec
#
# Epoch 63 Batch 0 Loss 0.0667
# Epoch 63 Batch 10 Loss 0.0635
# Epoch 63 Batch 20 Loss 0.0661
# Epoch 63 Batch 30 Loss 0.0621
# Epoch 63 Loss 0.0610
# Time taken for 1 epoch 9.285772562026978 sec
#
# Epoch 64 Batch 0 Loss 0.0564
# Epoch 64 Batch 10 Loss 0.0488
# Epoch 64 Batch 20 Loss 0.0625
# Epoch 64 Batch 30 Loss 0.0612
# Epoch 64 Loss 0.0582
# Time taken for 1 epoch 10.024987697601318 sec
#
# Epoch 65 Batch 0 Loss 0.0540
# Epoch 65 Batch 10 Loss 0.0503
# Epoch 65 Batch 20 Loss 0.0598
# Epoch 65 Batch 30 Loss 0.0681
# Epoch 65 Loss 0.0549
# Time taken for 1 epoch 9.310655355453491 sec
#
# Epoch 66 Batch 0 Loss 0.0429
# Epoch 66 Batch 10 Loss 0.0512
# Epoch 66 Batch 20 Loss 0.0608
# Epoch 66 Batch 30 Loss 0.0683
# Epoch 66 Loss 0.0521
# Time taken for 1 epoch 9.766302585601807 sec
#
# Epoch 67 Batch 0 Loss 0.0482
# Epoch 67 Batch 10 Loss 0.0438
# Epoch 67 Batch 20 Loss 0.0718
# Epoch 67 Batch 30 Loss 0.0586
# Epoch 67 Loss 0.0537
# Time taken for 1 epoch 9.26383376121521 sec
#
# Epoch 68 Batch 0 Loss 0.0489
# Epoch 68 Batch 10 Loss 0.0475
# Epoch 68 Batch 20 Loss 0.0471
# Epoch 68 Batch 30 Loss 0.0520
# Epoch 68 Loss 0.0529
# Time taken for 1 epoch 9.843034744262695 sec
#
# Epoch 69 Batch 0 Loss 0.0462
# Epoch 69 Batch 10 Loss 0.0659
# Epoch 69 Batch 20 Loss 0.0558
# Epoch 69 Batch 30 Loss 0.0738
# Epoch 69 Loss 0.0606
# Time taken for 1 epoch 9.276286602020264 sec
#
# Epoch 70 Batch 0 Loss 0.0469
# Epoch 70 Batch 10 Loss 0.0640
# Epoch 70 Batch 20 Loss 0.0682
# Epoch 70 Batch 30 Loss 0.0540
# Epoch 70 Loss 0.0571
# Time taken for 1 epoch 9.898587942123413 sec
#
# Epoch 71 Batch 0 Loss 0.0427
# Epoch 71 Batch 10 Loss 0.0409
# Epoch 71 Batch 20 Loss 0.0485
# Epoch 71 Batch 30 Loss 0.0620
# Epoch 71 Loss 0.0499
# Time taken for 1 epoch 9.307019710540771 sec
#
# Epoch 72 Batch 0 Loss 0.0491
# Epoch 72 Batch 10 Loss 0.0461
# Epoch 72 Batch 20 Loss 0.0444
# Epoch 72 Batch 30 Loss 0.0603
# Epoch 72 Loss 0.0460
# Time taken for 1 epoch 10.01865029335022 sec
#
# Epoch 73 Batch 0 Loss 0.0372
# Epoch 73 Batch 10 Loss 0.0385
# Epoch 73 Batch 20 Loss 0.0457
# Epoch 73 Batch 30 Loss 0.0461
# Epoch 73 Loss 0.0416
# Time taken for 1 epoch 9.295085430145264 sec
#
# Epoch 74 Batch 0 Loss 0.0349
# Epoch 74 Batch 10 Loss 0.0357
# Epoch 74 Batch 20 Loss 0.0388
# Epoch 74 Batch 30 Loss 0.0361
# Epoch 74 Loss 0.0376
# Time taken for 1 epoch 10.010104894638062 sec
#
# Epoch 75 Batch 0 Loss 0.0360
# Epoch 75 Batch 10 Loss 0.0385
# Epoch 75 Batch 20 Loss 0.0312
# Epoch 75 Batch 30 Loss 0.0350
# Epoch 75 Loss 0.0351
# Time taken for 1 epoch 9.297301054000854 sec
#
# Epoch 76 Batch 0 Loss 0.0279
# Epoch 76 Batch 10 Loss 0.0341
# Epoch 76 Batch 20 Loss 0.0359
# Epoch 76 Batch 30 Loss 0.0308
# Epoch 76 Loss 0.0327
# Time taken for 1 epoch 9.900640964508057 sec
#
# Epoch 77 Batch 0 Loss 0.0244
# Epoch 77 Batch 10 Loss 0.0369
# Epoch 77 Batch 20 Loss 0.0319
# Epoch 77 Batch 30 Loss 0.0355
# Epoch 77 Loss 0.0311
# Time taken for 1 epoch 9.30794620513916 sec
#
# Epoch 78 Batch 0 Loss 0.0242
# Epoch 78 Batch 10 Loss 0.0297
# Epoch 78 Batch 20 Loss 0.0268
# Epoch 78 Batch 30 Loss 0.0347
# Epoch 78 Loss 0.0295
# Time taken for 1 epoch 9.892786741256714 sec
#
# Epoch 79 Batch 0 Loss 0.0256
# Epoch 79 Batch 10 Loss 0.0259
# Epoch 79 Batch 20 Loss 0.0293
# Epoch 79 Batch 30 Loss 0.0302
# Epoch 79 Loss 0.0281
# Time taken for 1 epoch 9.3108229637146 sec
#
# Epoch 80 Batch 0 Loss 0.0277
# Epoch 80 Batch 10 Loss 0.0255
# Epoch 80 Batch 20 Loss 0.0281
# Epoch 80 Batch 30 Loss 0.0255
# Epoch 80 Loss 0.0267
# Time taken for 1 epoch 9.8563711643219 sec
#
# Epoch 81 Batch 0 Loss 0.0218
# Epoch 81 Batch 10 Loss 0.0257
# Epoch 81 Batch 20 Loss 0.0273
# Epoch 81 Batch 30 Loss 0.0217
# Epoch 81 Loss 0.0255
# Time taken for 1 epoch 9.278698444366455 sec
#
# Epoch 82 Batch 0 Loss 0.0208
# Epoch 82 Batch 10 Loss 0.0226
# Epoch 82 Batch 20 Loss 0.0270
# Epoch 82 Batch 30 Loss 0.0273
# Epoch 82 Loss 0.0243
# Time taken for 1 epoch 9.888082265853882 sec
#
# Epoch 83 Batch 0 Loss 0.0258
# Epoch 83 Batch 10 Loss 0.0193
# Epoch 83 Batch 20 Loss 0.0266
# Epoch 83 Batch 30 Loss 0.0250
# Epoch 83 Loss 0.0232
# Time taken for 1 epoch 9.27168869972229 sec
#
# Epoch 84 Batch 0 Loss 0.0195
# Epoch 84 Batch 10 Loss 0.0174
# Epoch 84 Batch 20 Loss 0.0244
# Epoch 84 Batch 30 Loss 0.0240
# Epoch 84 Loss 0.0222
# Time taken for 1 epoch 9.896862030029297 sec
#
# Epoch 85 Batch 0 Loss 0.0174
# Epoch 85 Batch 10 Loss 0.0197
# Epoch 85 Batch 20 Loss 0.0221
# Epoch 85 Batch 30 Loss 0.0254
# Epoch 85 Loss 0.0213
# Time taken for 1 epoch 9.276947975158691 sec
#
# Epoch 86 Batch 0 Loss 0.0127
# Epoch 86 Batch 10 Loss 0.0185
# Epoch 86 Batch 20 Loss 0.0275
# Epoch 86 Batch 30 Loss 0.0198
# Epoch 86 Loss 0.0203
# Time taken for 1 epoch 9.874889850616455 sec
#
# Epoch 87 Batch 0 Loss 0.0184
# Epoch 87 Batch 10 Loss 0.0243
# Epoch 87 Batch 20 Loss 0.0202
# Epoch 87 Batch 30 Loss 0.0198
# Epoch 87 Loss 0.0196
# Time taken for 1 epoch 9.28222393989563 sec
#
# Epoch 88 Batch 0 Loss 0.0223
# Epoch 88 Batch 10 Loss 0.0172
# Epoch 88 Batch 20 Loss 0.0201
# Epoch 88 Batch 30 Loss 0.0187
# Epoch 88 Loss 0.0186
# Time taken for 1 epoch 10.000102758407593 sec
#
# Epoch 89 Batch 0 Loss 0.0174
# Epoch 89 Batch 10 Loss 0.0184
# Epoch 89 Batch 20 Loss 0.0161
# Epoch 89 Batch 30 Loss 0.0209
# Epoch 89 Loss 0.0179
# Time taken for 1 epoch 9.297363758087158 sec
#
# Epoch 90 Batch 0 Loss 0.0154
# Epoch 90 Batch 10 Loss 0.0184
# Epoch 90 Batch 20 Loss 0.0160
# Epoch 90 Batch 30 Loss 0.0194
# Epoch 90 Loss 0.0171
# Time taken for 1 epoch 10.06306004524231 sec
#
# Epoch 91 Batch 0 Loss 0.0143
# Epoch 91 Batch 10 Loss 0.0167
# Epoch 91 Batch 20 Loss 0.0179
# Epoch 91 Batch 30 Loss 0.0198
# Epoch 91 Loss 0.0162
# Time taken for 1 epoch 9.275094032287598 sec
#
# Epoch 92 Batch 0 Loss 0.0133
# Epoch 92 Batch 10 Loss 0.0140
# Epoch 92 Batch 20 Loss 0.0190
# Epoch 92 Batch 30 Loss 0.0174
# Epoch 92 Loss 0.0154
# Time taken for 1 epoch 9.903006553649902 sec
#
# Epoch 93 Batch 0 Loss 0.0144
# Epoch 93 Batch 10 Loss 0.0148
# Epoch 93 Batch 20 Loss 0.0133
# Epoch 93 Batch 30 Loss 0.0130
# Epoch 93 Loss 0.0148
# Time taken for 1 epoch 9.30283522605896 sec
#
# Epoch 94 Batch 0 Loss 0.0094
# Epoch 94 Batch 10 Loss 0.0179
# Epoch 94 Batch 20 Loss 0.0151
# Epoch 94 Batch 30 Loss 0.0153
# Epoch 94 Loss 0.0141
# Time taken for 1 epoch 9.898418188095093 sec
#
# Epoch 95 Batch 0 Loss 0.0132
# Epoch 95 Batch 10 Loss 0.0124
# Epoch 95 Batch 20 Loss 0.0147
# Epoch 95 Batch 30 Loss 0.0164
# Epoch 95 Loss 0.0134
# Time taken for 1 epoch 9.28092098236084 sec
#
# Epoch 96 Batch 0 Loss 0.0097
# Epoch 96 Batch 10 Loss 0.0114
# Epoch 96 Batch 20 Loss 0.0131
# Epoch 96 Batch 30 Loss 0.0147
# Epoch 96 Loss 0.0131
# Time taken for 1 epoch 10.618959665298462 sec
#
# Epoch 97 Batch 0 Loss 0.0104
# Epoch 97 Batch 10 Loss 0.0102
# Epoch 97 Batch 20 Loss 0.0138
# Epoch 97 Batch 30 Loss 0.0163
# Epoch 97 Loss 0.0129
# Time taken for 1 epoch 9.405842304229736 sec
#
# Epoch 98 Batch 0 Loss 0.0126
# Epoch 98 Batch 10 Loss 0.0146
# Epoch 98 Batch 20 Loss 0.0147
# Epoch 98 Batch 30 Loss 0.0150
# Epoch 98 Loss 0.0130
# Time taken for 1 epoch 10.183180093765259 sec
#
# Epoch 99 Batch 0 Loss 0.0150
# Epoch 99 Batch 10 Loss 0.0131
# Epoch 99 Batch 20 Loss 0.0119
# Epoch 99 Batch 30 Loss 0.0200
# Epoch 99 Loss 0.0133
# Time taken for 1 epoch 9.449120044708252 sec
#
# Epoch 100 Batch 0 Loss 0.0098
# Epoch 100 Batch 10 Loss 0.0116
# Epoch 100 Batch 20 Loss 0.0150
# Epoch 100 Batch 30 Loss 0.0152
# Epoch 100 Loss 0.0123
# Time taken for 1 epoch 9.922706842422485 sec
#
# Epoch 101 Batch 0 Loss 0.0110
# Epoch 101 Batch 10 Loss 0.0122
# Epoch 101 Batch 20 Loss 0.0092
# Epoch 101 Batch 30 Loss 0.0133
# Epoch 101 Loss 0.0113
# Time taken for 1 epoch 9.30997347831726 sec
#
# Epoch 102 Batch 0 Loss 0.0084
# Epoch 102 Batch 10 Loss 0.0100
# Epoch 102 Batch 20 Loss 0.0133
# Epoch 102 Batch 30 Loss 0.0120
# Epoch 102 Loss 0.0106
# Time taken for 1 epoch 9.920610189437866 sec
#
# Epoch 103 Batch 0 Loss 0.0089
# Epoch 103 Batch 10 Loss 0.0084
# Epoch 103 Batch 20 Loss 0.0101
# Epoch 103 Batch 30 Loss 0.0117
# Epoch 103 Loss 0.0098
# Time taken for 1 epoch 9.294554710388184 sec
#
# Epoch 104 Batch 0 Loss 0.0069
# Epoch 104 Batch 10 Loss 0.0088
# Epoch 104 Batch 20 Loss 0.0084
# Epoch 104 Batch 30 Loss 0.0100
# Epoch 104 Loss 0.0090
# Time taken for 1 epoch 9.850922584533691 sec
#
# Epoch 105 Batch 0 Loss 0.0075
# Epoch 105 Batch 10 Loss 0.0087
# Epoch 105 Batch 20 Loss 0.0084
# Epoch 105 Batch 30 Loss 0.0088
# Epoch 105 Loss 0.0084
# Time taken for 1 epoch 9.271301984786987 sec
#
# Epoch 106 Batch 0 Loss 0.0063
# Epoch 106 Batch 10 Loss 0.0067
# Epoch 106 Batch 20 Loss 0.0069
# Epoch 106 Batch 30 Loss 0.0115
# Epoch 106 Loss 0.0081
# Time taken for 1 epoch 9.886542558670044 sec
#
# Epoch 107 Batch 0 Loss 0.0086
# Epoch 107 Batch 10 Loss 0.0078
# Epoch 107 Batch 20 Loss 0.0083
# Epoch 107 Batch 30 Loss 0.0080
# Epoch 107 Loss 0.0079
# Time taken for 1 epoch 9.289141654968262 sec
#
# Epoch 108 Batch 0 Loss 0.0083
# Epoch 108 Batch 10 Loss 0.0058
# Epoch 108 Batch 20 Loss 0.0067
# Epoch 108 Batch 30 Loss 0.0068
# Epoch 108 Loss 0.0073
# Time taken for 1 epoch 9.91183853149414 sec
#
# Epoch 109 Batch 0 Loss 0.0061
# Epoch 109 Batch 10 Loss 0.0063
# Epoch 109 Batch 20 Loss 0.0080
# Epoch 109 Batch 30 Loss 0.0070
# Epoch 109 Loss 0.0069
# Time taken for 1 epoch 10.230944633483887 sec
#
# Epoch 110 Batch 0 Loss 0.0059
# Epoch 110 Batch 10 Loss 0.0068
# Epoch 110 Batch 20 Loss 0.0069
# Epoch 110 Batch 30 Loss 0.0053
# Epoch 110 Loss 0.0067
# Time taken for 1 epoch 10.841107845306396 sec
#
# Epoch 111 Batch 0 Loss 0.0057
# Epoch 111 Batch 10 Loss 0.0050
# Epoch 111 Batch 20 Loss 0.0064
# Epoch 111 Batch 30 Loss 0.0067
# Epoch 111 Loss 0.0063
# Time taken for 1 epoch 9.262215852737427 sec
#
# Epoch 112 Batch 0 Loss 0.0058
# Epoch 112 Batch 10 Loss 0.0072
# Epoch 112 Batch 20 Loss 0.0057
# Epoch 112 Batch 30 Loss 0.0056
# Epoch 112 Loss 0.0061
# Time taken for 1 epoch 9.904550790786743 sec
#
# Epoch 113 Batch 0 Loss 0.0062
# Epoch 113 Batch 10 Loss 0.0063
# Epoch 113 Batch 20 Loss 0.0051
# Epoch 113 Batch 30 Loss 0.0064
# Epoch 113 Loss 0.0059
# Time taken for 1 epoch 9.282857179641724 sec
#
# Epoch 114 Batch 0 Loss 0.0061
# Epoch 114 Batch 10 Loss 0.0063
# Epoch 114 Batch 20 Loss 0.0058
# Epoch 114 Batch 30 Loss 0.0067
# Epoch 114 Loss 0.0056
# Time taken for 1 epoch 9.908447742462158 sec
#
# Epoch 115 Batch 0 Loss 0.0047
# Epoch 115 Batch 10 Loss 0.0060
# Epoch 115 Batch 20 Loss 0.0076
# Epoch 115 Batch 30 Loss 0.0064
# Epoch 115 Loss 0.0054
# Time taken for 1 epoch 9.272613763809204 sec
#
# Epoch 116 Batch 0 Loss 0.0063
# Epoch 116 Batch 10 Loss 0.0044
# Epoch 116 Batch 20 Loss 0.0045
# Epoch 116 Batch 30 Loss 0.0048
# Epoch 116 Loss 0.0052
# Time taken for 1 epoch 9.878715991973877 sec
#
# Epoch 117 Batch 0 Loss 0.0050
# Epoch 117 Batch 10 Loss 0.0044
# Epoch 117 Batch 20 Loss 0.0059
# Epoch 117 Batch 30 Loss 0.0052
# Epoch 117 Loss 0.0050
# Time taken for 1 epoch 9.311617374420166 sec
#
# Epoch 118 Batch 0 Loss 0.0050
# Epoch 118 Batch 10 Loss 0.0053
# Epoch 118 Batch 20 Loss 0.0056
# Epoch 118 Batch 30 Loss 0.0062
# Epoch 118 Loss 0.0048
# Time taken for 1 epoch 9.863685131072998 sec
#
# Epoch 119 Batch 0 Loss 0.0046
# Epoch 119 Batch 10 Loss 0.0038
# Epoch 119 Batch 20 Loss 0.0046
# Epoch 119 Batch 30 Loss 0.0062
# Epoch 119 Loss 0.0047
# Time taken for 1 epoch 9.289774179458618 sec
#
# Epoch 120 Batch 0 Loss 0.0041
# Epoch 120 Batch 10 Loss 0.0054
# Epoch 120 Batch 20 Loss 0.0049
# Epoch 120 Batch 30 Loss 0.0048
# Epoch 120 Loss 0.0045
# Time taken for 1 epoch 9.894559860229492 sec
#
# Epoch 121 Batch 0 Loss 0.0039
# Epoch 121 Batch 10 Loss 0.0034
# Epoch 121 Batch 20 Loss 0.0048
# Epoch 121 Batch 30 Loss 0.0052
# Epoch 121 Loss 0.0044
# Time taken for 1 epoch 9.291216850280762 sec
#
# Epoch 122 Batch 0 Loss 0.0042
# Epoch 122 Batch 10 Loss 0.0041
# Epoch 122 Batch 20 Loss 0.0036
# Epoch 122 Batch 30 Loss 0.0043
# Epoch 122 Loss 0.0042
# Time taken for 1 epoch 9.884366035461426 sec
#
# Epoch 123 Batch 0 Loss 0.0039
# Epoch 123 Batch 10 Loss 0.0041
# Epoch 123 Batch 20 Loss 0.0036
# Epoch 123 Batch 30 Loss 0.0044
# Epoch 123 Loss 0.0040
# Time taken for 1 epoch 9.276326417922974 sec
#
# Epoch 124 Batch 0 Loss 0.0042
# Epoch 124 Batch 10 Loss 0.0039
# Epoch 124 Batch 20 Loss 0.0032
# Epoch 124 Batch 30 Loss 0.0045
# Epoch 124 Loss 0.0039
# Time taken for 1 epoch 9.899491786956787 sec
#
# Epoch 125 Batch 0 Loss 0.0033
# Epoch 125 Batch 10 Loss 0.0037
# Epoch 125 Batch 20 Loss 0.0035
# Epoch 125 Batch 30 Loss 0.0044
# Epoch 125 Loss 0.0038
# Time taken for 1 epoch 9.26264500617981 sec
#
# Epoch 126 Batch 0 Loss 0.0037
# Epoch 126 Batch 10 Loss 0.0031
# Epoch 126 Batch 20 Loss 0.0039
# Epoch 126 Batch 30 Loss 0.0039
# Epoch 126 Loss 0.0036
# Time taken for 1 epoch 9.879989862442017 sec
#
# Epoch 127 Batch 0 Loss 0.0030
# Epoch 127 Batch 10 Loss 0.0035
# Epoch 127 Batch 20 Loss 0.0030
# Epoch 127 Batch 30 Loss 0.0037
# Epoch 127 Loss 0.0035
# Time taken for 1 epoch 9.314178705215454 sec
#
# Epoch 128 Batch 0 Loss 0.0031
# Epoch 128 Batch 10 Loss 0.0034
# Epoch 128 Batch 20 Loss 0.0038
# Epoch 128 Batch 30 Loss 0.0036
# Epoch 128 Loss 0.0034
# Time taken for 1 epoch 9.907732009887695 sec
#
# Epoch 129 Batch 0 Loss 0.0035
# Epoch 129 Batch 10 Loss 0.0032
# Epoch 129 Batch 20 Loss 0.0038
# Epoch 129 Batch 30 Loss 0.0035
# Epoch 129 Loss 0.0033
# Time taken for 1 epoch 9.274945735931396 sec
#
# Epoch 130 Batch 0 Loss 0.0030
# Epoch 130 Batch 10 Loss 0.0030
# Epoch 130 Batch 20 Loss 0.0031
# Epoch 130 Batch 30 Loss 0.0039
# Epoch 130 Loss 0.0032
# Time taken for 1 epoch 9.998583555221558 sec
#
# Epoch 131 Batch 0 Loss 0.0030
# Epoch 131 Batch 10 Loss 0.0029
# Epoch 131 Batch 20 Loss 0.0029
# Epoch 131 Batch 30 Loss 0.0032
# Epoch 131 Loss 0.0031
# Time taken for 1 epoch 9.27879023551941 sec
#
# Epoch 132 Batch 0 Loss 0.0027
# Epoch 132 Batch 10 Loss 0.0025
# Epoch 132 Batch 20 Loss 0.0034
# Epoch 132 Batch 30 Loss 0.0032
# Epoch 132 Loss 0.0030
# Time taken for 1 epoch 9.896799087524414 sec
#
# Epoch 133 Batch 0 Loss 0.0025
# Epoch 133 Batch 10 Loss 0.0030
# Epoch 133 Batch 20 Loss 0.0036
# Epoch 133 Batch 30 Loss 0.0029
# Epoch 133 Loss 0.0029
# Time taken for 1 epoch 9.313208103179932 sec
#
# Epoch 134 Batch 0 Loss 0.0034
# Epoch 134 Batch 10 Loss 0.0030
# Epoch 134 Batch 20 Loss 0.0022
# Epoch 134 Batch 30 Loss 0.0033
# Epoch 134 Loss 0.0028
# Time taken for 1 epoch 9.933112621307373 sec
#
# Epoch 135 Batch 0 Loss 0.0035
# Epoch 135 Batch 10 Loss 0.0024
# Epoch 135 Batch 20 Loss 0.0024
# Epoch 135 Batch 30 Loss 0.0026
# Epoch 135 Loss 0.0027
# Time taken for 1 epoch 9.303477048873901 sec
#
# Epoch 136 Batch 0 Loss 0.0023
# Epoch 136 Batch 10 Loss 0.0029
# Epoch 136 Batch 20 Loss 0.0029
# Epoch 136 Batch 30 Loss 0.0026
# Epoch 136 Loss 0.0027
# Time taken for 1 epoch 9.886812448501587 sec
#
# Epoch 137 Batch 0 Loss 0.0024
# Epoch 137 Batch 10 Loss 0.0019
# Epoch 137 Batch 20 Loss 0.0026
# Epoch 137 Batch 30 Loss 0.0023
# Epoch 137 Loss 0.0026
# Time taken for 1 epoch 9.289930820465088 sec
#
# Epoch 138 Batch 0 Loss 0.0023
# Epoch 138 Batch 10 Loss 0.0023
# Epoch 138 Batch 20 Loss 0.0029
# Epoch 138 Batch 30 Loss 0.0021
# Epoch 138 Loss 0.0025
# Time taken for 1 epoch 9.894455909729004 sec
#
# Epoch 139 Batch 0 Loss 0.0023
# Epoch 139 Batch 10 Loss 0.0032
# Epoch 139 Batch 20 Loss 0.0026
# Epoch 139 Batch 30 Loss 0.0028
# Epoch 139 Loss 0.0024
# Time taken for 1 epoch 9.30229663848877 sec
#
# Epoch 140 Batch 0 Loss 0.0020
# Epoch 140 Batch 10 Loss 0.0025
# Epoch 140 Batch 20 Loss 0.0021
# Epoch 140 Batch 30 Loss 0.0031
# Epoch 140 Loss 0.0024
# Time taken for 1 epoch 9.898773193359375 sec
#
# Epoch 141 Batch 0 Loss 0.0020
# Epoch 141 Batch 10 Loss 0.0027
# Epoch 141 Batch 20 Loss 0.0021
# Epoch 141 Batch 30 Loss 0.0024
# Epoch 141 Loss 0.0023
# Time taken for 1 epoch 9.317630052566528 sec
#
# Epoch 142 Batch 0 Loss 0.0021
# Epoch 142 Batch 10 Loss 0.0021
# Epoch 142 Batch 20 Loss 0.0021
# Epoch 142 Batch 30 Loss 0.0022
# Epoch 142 Loss 0.0022
# Time taken for 1 epoch 9.904410600662231 sec
#
# Epoch 143 Batch 0 Loss 0.0019
# Epoch 143 Batch 10 Loss 0.0020
# Epoch 143 Batch 20 Loss 0.0024
# Epoch 143 Batch 30 Loss 0.0021
# Epoch 143 Loss 0.0022
# Time taken for 1 epoch 9.304866790771484 sec
#
# Epoch 144 Batch 0 Loss 0.0018
# Epoch 144 Batch 10 Loss 0.0021
# Epoch 144 Batch 20 Loss 0.0023
# Epoch 144 Batch 30 Loss 0.0021
# Epoch 144 Loss 0.0021
# Time taken for 1 epoch 9.88578987121582 sec
#
# Epoch 145 Batch 0 Loss 0.0021
# Epoch 145 Batch 10 Loss 0.0019
# Epoch 145 Batch 20 Loss 0.0021
# Epoch 145 Batch 30 Loss 0.0020
# Epoch 145 Loss 0.0020
# Time taken for 1 epoch 9.298531770706177 sec
#
# Epoch 146 Batch 0 Loss 0.0017
# Epoch 146 Batch 10 Loss 0.0019
# Epoch 146 Batch 20 Loss 0.0023
# Epoch 146 Batch 30 Loss 0.0023
# Epoch 146 Loss 0.0020
# Time taken for 1 epoch 9.894420146942139 sec
#
# Epoch 147 Batch 0 Loss 0.0019
# Epoch 147 Batch 10 Loss 0.0019
# Epoch 147 Batch 20 Loss 0.0017
# Epoch 147 Batch 30 Loss 0.0018
# Epoch 147 Loss 0.0019
# Time taken for 1 epoch 9.294384241104126 sec
#
# Epoch 148 Batch 0 Loss 0.0016
# Epoch 148 Batch 10 Loss 0.0019
# Epoch 148 Batch 20 Loss 0.0018
# Epoch 148 Batch 30 Loss 0.0021
# Epoch 148 Loss 0.0019
# Time taken for 1 epoch 9.888916730880737 sec
#
# Epoch 149 Batch 0 Loss 0.0019
# Epoch 149 Batch 10 Loss 0.0022
# Epoch 149 Batch 20 Loss 0.0019
# Epoch 149 Batch 30 Loss 0.0018
# Epoch 149 Loss 0.0018
# Time taken for 1 epoch 9.272650241851807 sec
#
# Epoch 150 Batch 0 Loss 0.0016
# Epoch 150 Batch 10 Loss 0.0016
# Epoch 150 Batch 20 Loss 0.0017
# Epoch 150 Batch 30 Loss 0.0018
# Epoch 150 Loss 0.0018
# Time taken for 1 epoch 9.901995420455933 sec
#
# Epoch 151 Batch 0 Loss 0.0017
# Epoch 151 Batch 10 Loss 0.0017
# Epoch 151 Batch 20 Loss 0.0016
# Epoch 151 Batch 30 Loss 0.0015
# Epoch 151 Loss 0.0017
# Time taken for 1 epoch 9.300313234329224 sec
#
# Epoch 152 Batch 0 Loss 0.0016
# Epoch 152 Batch 10 Loss 0.0013
# Epoch 152 Batch 20 Loss 0.0018
# Epoch 152 Batch 30 Loss 0.0020
# Epoch 152 Loss 0.0017
# Time taken for 1 epoch 9.846579790115356 sec
#
# Epoch 153 Batch 0 Loss 0.0015
# Epoch 153 Batch 10 Loss 0.0014
# Epoch 153 Batch 20 Loss 0.0016
# Epoch 153 Batch 30 Loss 0.0017
# Epoch 153 Loss 0.0017
# Time taken for 1 epoch 9.295377492904663 sec
#
# Epoch 154 Batch 0 Loss 0.0016
# Epoch 154 Batch 10 Loss 0.0014
# Epoch 154 Batch 20 Loss 0.0014
# Epoch 154 Batch 30 Loss 0.0018
# Epoch 154 Loss 0.0016
# Time taken for 1 epoch 9.90916395187378 sec
#
# Epoch 155 Batch 0 Loss 0.0017
# Epoch 155 Batch 10 Loss 0.0015
# Epoch 155 Batch 20 Loss 0.0016
# Epoch 155 Batch 30 Loss 0.0017
# Epoch 155 Loss 0.0016
# Time taken for 1 epoch 9.296945810317993 sec
#
# Epoch 156 Batch 0 Loss 0.0014
# Epoch 156 Batch 10 Loss 0.0015
# Epoch 156 Batch 20 Loss 0.0015
# Epoch 156 Batch 30 Loss 0.0016
# Epoch 156 Loss 0.0015
# Time taken for 1 epoch 9.934857606887817 sec
#
# Epoch 157 Batch 0 Loss 0.0012
# Epoch 157 Batch 10 Loss 0.0015
# Epoch 157 Batch 20 Loss 0.0015
# Epoch 157 Batch 30 Loss 0.0017
# Epoch 157 Loss 0.0015
# Time taken for 1 epoch 9.298514604568481 sec
#
# Epoch 158 Batch 0 Loss 0.0016
# Epoch 158 Batch 10 Loss 0.0016
# Epoch 158 Batch 20 Loss 0.0016
# Epoch 158 Batch 30 Loss 0.0016
# Epoch 158 Loss 0.0015
# Time taken for 1 epoch 9.925389766693115 sec
#
# Epoch 159 Batch 0 Loss 0.0014
# Epoch 159 Batch 10 Loss 0.0013
# Epoch 159 Batch 20 Loss 0.0013
# Epoch 159 Batch 30 Loss 0.0016
# Epoch 159 Loss 0.0014
# Time taken for 1 epoch 9.29100227355957 sec
#
# Epoch 160 Batch 0 Loss 0.0014
# Epoch 160 Batch 10 Loss 0.0013
# Epoch 160 Batch 20 Loss 0.0013
# Epoch 160 Batch 30 Loss 0.0013
# Epoch 160 Loss 0.0014
# Time taken for 1 epoch 9.893132209777832 sec
#
# Epoch 161 Batch 0 Loss 0.0014
# Epoch 161 Batch 10 Loss 0.0014
# Epoch 161 Batch 20 Loss 0.0013
# Epoch 161 Batch 30 Loss 0.0013
# Epoch 161 Loss 0.0014
# Time taken for 1 epoch 9.288874864578247 sec
#
# Epoch 162 Batch 0 Loss 0.0013
# Epoch 162 Batch 10 Loss 0.0012
# Epoch 162 Batch 20 Loss 0.0014
# Epoch 162 Batch 30 Loss 0.0013
# Epoch 162 Loss 0.0013
# Time taken for 1 epoch 9.880157232284546 sec
#
# Epoch 163 Batch 0 Loss 0.0016
# Epoch 163 Batch 10 Loss 0.0012
# Epoch 163 Batch 20 Loss 0.0012
# Epoch 163 Batch 30 Loss 0.0015
# Epoch 163 Loss 0.0013
# Time taken for 1 epoch 9.286945819854736 sec
#
# Epoch 164 Batch 0 Loss 0.0012
# Epoch 164 Batch 10 Loss 0.0011
# Epoch 164 Batch 20 Loss 0.0012
# Epoch 164 Batch 30 Loss 0.0013
# Epoch 164 Loss 0.0013
# Time taken for 1 epoch 9.903983354568481 sec
#
# Epoch 165 Batch 0 Loss 0.0012
# Epoch 165 Batch 10 Loss 0.0011
# Epoch 165 Batch 20 Loss 0.0014
# Epoch 165 Batch 30 Loss 0.0013
# Epoch 165 Loss 0.0012
# Time taken for 1 epoch 9.3043692111969 sec
#
# Epoch 166 Batch 0 Loss 0.0013
# Epoch 166 Batch 10 Loss 0.0012
# Epoch 166 Batch 20 Loss 0.0011
# Epoch 166 Batch 30 Loss 0.0013
# Epoch 166 Loss 0.0012
# Time taken for 1 epoch 9.903788089752197 sec
#
# Epoch 167 Batch 0 Loss 0.0011
# Epoch 167 Batch 10 Loss 0.0010
# Epoch 167 Batch 20 Loss 0.0011
# Epoch 167 Batch 30 Loss 0.0013
# Epoch 167 Loss 0.0012
# Time taken for 1 epoch 9.287595272064209 sec
#
# Epoch 168 Batch 0 Loss 0.0010
# Epoch 168 Batch 10 Loss 0.0011
# Epoch 168 Batch 20 Loss 0.0011
# Epoch 168 Batch 30 Loss 0.0014
# Epoch 168 Loss 0.0011
# Time taken for 1 epoch 9.903156757354736 sec
#
# Epoch 169 Batch 0 Loss 0.0011
# Epoch 169 Batch 10 Loss 0.0011
# Epoch 169 Batch 20 Loss 0.0012
# Epoch 169 Batch 30 Loss 0.0013
# Epoch 169 Loss 0.0011
# Time taken for 1 epoch 9.262509822845459 sec
#
# Epoch 170 Batch 0 Loss 0.0010
# Epoch 170 Batch 10 Loss 0.0009
# Epoch 170 Batch 20 Loss 0.0010
# Epoch 170 Batch 30 Loss 0.0010
# Epoch 170 Loss 0.0011
# Time taken for 1 epoch 9.905622005462646 sec
#
# Epoch 171 Batch 0 Loss 0.0011
# Epoch 171 Batch 10 Loss 0.0012
# Epoch 171 Batch 20 Loss 0.0010
# Epoch 171 Batch 30 Loss 0.0012
# Epoch 171 Loss 0.0011
# Time taken for 1 epoch 9.316443681716919 sec
#
# Epoch 172 Batch 0 Loss 0.0010
# Epoch 172 Batch 10 Loss 0.0010
# Epoch 172 Batch 20 Loss 0.0012
# Epoch 172 Batch 30 Loss 0.0011
# Epoch 172 Loss 0.0010
# Time taken for 1 epoch 9.930776834487915 sec
#
# Epoch 173 Batch 0 Loss 0.0010
# Epoch 173 Batch 10 Loss 0.0010
# Epoch 173 Batch 20 Loss 0.0010
# Epoch 173 Batch 30 Loss 0.0010
# Epoch 173 Loss 0.0010
# Time taken for 1 epoch 9.323551893234253 sec
#
# Epoch 174 Batch 0 Loss 0.0010
# Epoch 174 Batch 10 Loss 0.0011
# Epoch 174 Batch 20 Loss 0.0012
# Epoch 174 Batch 30 Loss 0.0011
# Epoch 174 Loss 0.0010
# Time taken for 1 epoch 9.906815528869629 sec
#
# Epoch 175 Batch 0 Loss 0.0009
# Epoch 175 Batch 10 Loss 0.0009
# Epoch 175 Batch 20 Loss 0.0009
# Epoch 175 Batch 30 Loss 0.0008
# Epoch 175 Loss 0.0010
# Time taken for 1 epoch 9.300057649612427 sec
#
# Epoch 176 Batch 0 Loss 0.0010
# Epoch 176 Batch 10 Loss 0.0009
# Epoch 176 Batch 20 Loss 0.0010
# Epoch 176 Batch 30 Loss 0.0008
# Epoch 176 Loss 0.0010
# Time taken for 1 epoch 9.9071626663208 sec
#
# Epoch 177 Batch 0 Loss 0.0010
# Epoch 177 Batch 10 Loss 0.0010
# Epoch 177 Batch 20 Loss 0.0010
# Epoch 177 Batch 30 Loss 0.0009
# Epoch 177 Loss 0.0009
# Time taken for 1 epoch 9.318367004394531 sec
#
# Epoch 178 Batch 0 Loss 0.0011
# Epoch 178 Batch 10 Loss 0.0010
# Epoch 178 Batch 20 Loss 0.0009
# Epoch 178 Batch 30 Loss 0.0008
# Epoch 178 Loss 0.0009
# Time taken for 1 epoch 9.891409873962402 sec
#
# Epoch 179 Batch 0 Loss 0.0009
# Epoch 179 Batch 10 Loss 0.0008
# Epoch 179 Batch 20 Loss 0.0009
# Epoch 179 Batch 30 Loss 0.0010
# Epoch 179 Loss 0.0009
# Time taken for 1 epoch 9.291625261306763 sec
#
# Epoch 180 Batch 0 Loss 0.0009
# Epoch 180 Batch 10 Loss 0.0009
# Epoch 180 Batch 20 Loss 0.0009
# Epoch 180 Batch 30 Loss 0.0010
# Epoch 180 Loss 0.0009
# Time taken for 1 epoch 9.853237390518188 sec
#
# Epoch 181 Batch 0 Loss 0.0008
# Epoch 181 Batch 10 Loss 0.0009
# Epoch 181 Batch 20 Loss 0.0008
# Epoch 181 Batch 30 Loss 0.0009
# Epoch 181 Loss 0.0009
# Time taken for 1 epoch 9.27193832397461 sec
#
# Epoch 182 Batch 0 Loss 0.0008
# Epoch 182 Batch 10 Loss 0.0007
# Epoch 182 Batch 20 Loss 0.0009
# Epoch 182 Batch 30 Loss 0.0009
# Epoch 182 Loss 0.0008
# Time taken for 1 epoch 9.877875566482544 sec
#
# Epoch 183 Batch 0 Loss 0.0009
# Epoch 183 Batch 10 Loss 0.0009
# Epoch 183 Batch 20 Loss 0.0009
# Epoch 183 Batch 30 Loss 0.0008
# Epoch 183 Loss 0.0008
# Time taken for 1 epoch 9.294707775115967 sec
#
# Epoch 184 Batch 0 Loss 0.0008
# Epoch 184 Batch 10 Loss 0.0008
# Epoch 184 Batch 20 Loss 0.0009
# Epoch 184 Batch 30 Loss 0.0008
# Epoch 184 Loss 0.0008
# Time taken for 1 epoch 9.895768880844116 sec
#
# Epoch 185 Batch 0 Loss 0.0008
# Epoch 185 Batch 10 Loss 0.0008
# Epoch 185 Batch 20 Loss 0.0008
# Epoch 185 Batch 30 Loss 0.0008
# Epoch 185 Loss 0.0008
# Time taken for 1 epoch 9.263342380523682 sec
#
# Epoch 186 Batch 0 Loss 0.0007
# Epoch 186 Batch 10 Loss 0.0007
# Epoch 186 Batch 20 Loss 0.0007
# Epoch 186 Batch 30 Loss 0.0008
# Epoch 186 Loss 0.0008
# Time taken for 1 epoch 9.864841222763062 sec
#
# Epoch 187 Batch 0 Loss 0.0008
# Epoch 187 Batch 10 Loss 0.0007
# Epoch 187 Batch 20 Loss 0.0007
# Epoch 187 Batch 30 Loss 0.0008
# Epoch 187 Loss 0.0007
# Time taken for 1 epoch 9.266712188720703 sec
#
# Epoch 188 Batch 0 Loss 0.0007
# Epoch 188 Batch 10 Loss 0.0006
# Epoch 188 Batch 20 Loss 0.0007
# Epoch 188 Batch 30 Loss 0.0007
# Epoch 188 Loss 0.0007
# Time taken for 1 epoch 9.86890697479248 sec
#
# Epoch 189 Batch 0 Loss 0.0006
# Epoch 189 Batch 10 Loss 0.0007
# Epoch 189 Batch 20 Loss 0.0008
# Epoch 189 Batch 30 Loss 0.0007
# Epoch 189 Loss 0.0007
# Time taken for 1 epoch 9.275956630706787 sec
#
# Epoch 190 Batch 0 Loss 0.0007
# Epoch 190 Batch 10 Loss 0.0007
# Epoch 190 Batch 20 Loss 0.0007
# Epoch 190 Batch 30 Loss 0.0007
# Epoch 190 Loss 0.0007
# Time taken for 1 epoch 9.851959466934204 sec
#
# Epoch 191 Batch 0 Loss 0.0006
# Epoch 191 Batch 10 Loss 0.0007
# Epoch 191 Batch 20 Loss 0.0006
# Epoch 191 Batch 30 Loss 0.0006
# Epoch 191 Loss 0.0007
# Time taken for 1 epoch 9.250197649002075 sec
#
# Epoch 192 Batch 0 Loss 0.0007
# Epoch 192 Batch 10 Loss 0.0008
# Epoch 192 Batch 20 Loss 0.0006
# Epoch 192 Batch 30 Loss 0.0007
# Epoch 192 Loss 0.0007
# Time taken for 1 epoch 9.957149982452393 sec
#
# Epoch 193 Batch 0 Loss 0.0007
# Epoch 193 Batch 10 Loss 0.0006
# Epoch 193 Batch 20 Loss 0.0006
# Epoch 193 Batch 30 Loss 0.0008
# Epoch 193 Loss 0.0007
# Time taken for 1 epoch 9.311179399490356 sec
#
# Epoch 194 Batch 0 Loss 0.0005
# Epoch 194 Batch 10 Loss 0.0006
# Epoch 194 Batch 20 Loss 0.0006
# Epoch 194 Batch 30 Loss 0.0007
# Epoch 194 Loss 0.0006
# Time taken for 1 epoch 9.937943696975708 sec
#
# Epoch 195 Batch 0 Loss 0.0005
# Epoch 195 Batch 10 Loss 0.0007
# Epoch 195 Batch 20 Loss 0.0007
# Epoch 195 Batch 30 Loss 0.0007
# Epoch 195 Loss 0.0006
# Time taken for 1 epoch 9.280855894088745 sec
#
# Epoch 196 Batch 0 Loss 0.0006
# Epoch 196 Batch 10 Loss 0.0007
# Epoch 196 Batch 20 Loss 0.0006
# Epoch 196 Batch 30 Loss 0.0007
# Epoch 196 Loss 0.0006
# Time taken for 1 epoch 9.885751247406006 sec
#
# Epoch 197 Batch 0 Loss 0.0006
# Epoch 197 Batch 10 Loss 0.0006
# Epoch 197 Batch 20 Loss 0.0007
# Epoch 197 Batch 30 Loss 0.0006
# Epoch 197 Loss 0.0006
# Time taken for 1 epoch 9.286265850067139 sec
#
# Epoch 198 Batch 0 Loss 0.0006
# Epoch 198 Batch 10 Loss 0.0006
# Epoch 198 Batch 20 Loss 0.0006
# Epoch 198 Batch 30 Loss 0.0007
# Epoch 198 Loss 0.0006
# Time taken for 1 epoch 9.898112535476685 sec
#
# Epoch 199 Batch 0 Loss 0.0007
# Epoch 199 Batch 10 Loss 0.0005
# Epoch 199 Batch 20 Loss 0.0005
# Epoch 199 Batch 30 Loss 0.0006
# Epoch 199 Loss 0.0006
# Time taken for 1 epoch 9.274162769317627 sec
#
# Epoch 200 Batch 0 Loss 0.0005
# Epoch 200 Batch 10 Loss 0.0006
# Epoch 200 Batch 20 Loss 0.0006
# Epoch 200 Batch 30 Loss 0.0006
# Epoch 200 Loss 0.0006
# Time taken for 1 epoch 9.900630235671997 sec

# %% [markdown]
# Оценка модели

# %%
def evaluate(sentence):
    inputs = [tok_text.word_index[i] for i in sentence.split(' ') if i !='']
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                           maxlen=max_len_text,
                                                           padding='post')
    inputs = tf.convert_to_tensor(inputs)

    result = ''

    hidden = [tf.zeros((1, latent_dim))]
    enc_out, enc_hidden = encoder(inputs, hidden)

    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([tok_sum.word_index['bos']], 0)

    for t in range(max_len_sum):
        predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)

        predicted_id = tf.argmax(predictions[0]).numpy()

        result += tok_sum.index_word[predicted_id] + ' '

        if tok_sum.index_word[predicted_id] == 'eos':
            return result, sentence

        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence

# %%
def summ(sentence):
    result, sentence = evaluate(sentence)

    return result

# %%
#функция перевода последовательности индексов в текст
def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_text_index[i]+' '
    return newString
#функция перевода последовательности индексов в title
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=sum_wordindex['bos']) and i!=sum_wordindex['eos']):
            newString=newString+reverse_sum_index[i]+' '
    return newString

# %%
for i in range(5):
    text2 = seq2text(padded_x_test[i])
    print("Original title:", seq2summary(padded_x_test_sum[i]))
    print("Predicted title: ", summ(text2.strip()))
    print("\n")
# Out:
# Original title: или куда
# Predicted title:  станет уроком кузнецов извинился за скандальное видео eos
#
#
# Original title: «люди в
# Predicted title:  «отращивать усы не собираюсь» eos
#
#
# Original title: ссср как выборы
# Predicted title:  «спартак» не оценили eos
#
#
# Original title: «он с
# Predicted title:  миллиардер из общежития eos
#
#
# Original title: почему не пенсии
# Predicted title:  saab заведет русский миллиардер eos
